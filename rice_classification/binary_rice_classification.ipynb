# %%
# Background
"""I found this code on the google developer ML crash course
website and I really liked how they used the data classes
to organize the ML training so I adapted their architecture here"""
# Out:
# 'I found this code on the google developer ML crash course\nwebsite and I really liked how they used the data classes\nto organize the ML training so I adapted their architecture here'

# %%
# Load the imports

import keras
import numpy as np
import pandas as pd

from dataclasses import dataclass

import matplotlib.pyplot as plt

# %%
# Load the dataset
rice_dataset_raw = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/Rice_Cammeo_Osmancik.csv")

# %%
# Read and provide statistics on the dataset.
rice_dataset = rice_dataset_raw[[
    'Area',
    'Perimeter',
    'Major_Axis_Length',
    'Minor_Axis_Length',
    'Eccentricity',
    'Convex_Area',
    'Extent',
    'Class',
]]

rice_dataset.describe()
# Out:
#                Area    Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# count   3810.000000  3810.000000        3810.000000        3810.000000
# mean   12667.727559   454.239180         188.776222          86.313750
# std     1732.367706    35.597081          17.448679           5.729817
# min     7551.000000   359.100006         145.264465          59.532406
# 25%    11370.500000   426.144753         174.353855          82.731695
# 50%    12421.500000   448.852493         185.810059          86.434647
# 75%    13950.000000   483.683746         203.550438          90.143677
# max    18913.000000   548.445984         239.010498         107.542450
#
#        Eccentricity   Convex_Area       Extent
# count   3810.000000   3810.000000  3810.000000
# mean       0.886871  12952.496850     0.661934
# std        0.020818   1776.972042     0.077239
# min        0.777233   7723.000000     0.497413
# 25%        0.872402  11626.250000     0.598862
# 50%        0.889050  12706.500000     0.645361
# 75%        0.902588  14284.000000     0.726562
# max        0.948007  19099.000000     0.861050

# %%
# Normalize and transform the data

feature_mean = rice_dataset.mean(numeric_only=True)
feature_std = rice_dataset.std(numeric_only=True)
cols_of_numerical_features = rice_dataset.select_dtypes('number').columns

rice_dataset_normalized = (
    rice_dataset[cols_of_numerical_features] - feature_mean
    ) / feature_std

#copy the label to the new dataframe
rice_dataset_normalized['Class'] = rice_dataset['Class']

#add a column of binary labels representing the class
rice_dataset_normalized['Class_Bool'] = (
    #returns True if class is Cammeo and false ow
    rice_dataset_normalized['Class']=='Cammeo'
).astype(int)

rice_dataset_normalized.head()
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0  1.479635   2.004091           2.348238          -0.212915      2.018073
# 1  1.147720   1.125705           0.988261           0.945444      0.409964
# 2  1.135020   1.317041           1.451718           0.253854      1.212797
# 3  0.293398   0.115285           0.261405           0.198025      0.239720
# 4  1.166191   1.486858           1.316269           0.523351      0.952096
#
#    Convex_Area    Extent   Class  Class_Bool
# 0     1.499463 -1.152770  Cammeo           1
# 1     1.192761 -0.602000  Cammeo           1
# 2     1.126356  0.405558  Cammeo           1
# 3     0.233826 -0.275315  Cammeo           1
# 4     1.299685 -0.205986  Cammeo           1

# %%
# Create train, test, and validation datasets

#set the random seed
keras.utils.set_random_seed(42)

#we'll use an 80-10-10 split
num_samples = len(rice_dataset_normalized)
idx_80th = round(num_samples * 0.8)
idx_90th = idx_80th + round(num_samples * 0.1)

#shuffle the dataset randomly
data_shuffled = rice_dataset_normalized.sample(frac=1, random_state=100)

train_data = data_shuffled.iloc[0:idx_80th]
test_data = data_shuffled.iloc[idx_80th:idx_90th]
validation_data = data_shuffled.iloc[idx_90th:]

train_data.head()
# Out:
#           Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 2030 -2.076769  -2.223362          -1.821991          -2.109025     -0.274986
# 2225 -0.582860  -0.308402          -0.513622          -0.425379     -0.111876
# 1053  0.694583   1.189419           1.363689          -0.443210      1.546616
# 3685 -0.188602  -0.087737          -0.294041           0.066788     -0.255445
# 2976 -0.657324  -0.949044          -1.175949           0.379025     -1.744676
#
#       Convex_Area    Extent     Class  Class_Bool
# 2030    -2.093166  0.977027  Osmancik           0
# 2225    -0.522516 -0.891168  Osmancik           0
# 1053     0.783075 -1.736411    Cammeo           1
# 3685    -0.155600 -0.774437  Osmancik           0
# 2976    -0.677837  0.623452  Osmancik           0

# %%
# Extract the features and the labels from the train, test, and validation data

label_cols = ['Class', 'Class_Bool']

train_features = train_data.drop(columns=label_cols)
train_labels = train_data['Class_Bool'].to_numpy()
validation_features = validation_data.drop(columns=label_cols)
validation_labels = validation_data['Class_Bool'].to_numpy()
test_features = test_data.drop(columns=label_cols)
test_labels = test_data['Class_Bool'].to_numpy()

# %%
# Define data classes for the experiment and experiment settings

import keras.callbacks
import keras.layers


@dataclass
class ExperimentSettings:
    """Hyperparameters and list of input features used to train the model"""

    learning_rate: float
    num_epochs: int
    batch_size: int
    classification_threshold: float
    input_features: list[str]

@dataclass
class Experiment:
    """Stores the settings used for training and resulting model"""

    name: str
    settings: ExperimentSettings
    model: keras.Model
    epochs: np.ndarray
    metrics_history: keras.callbacks.History

    def get_final_metric_value(self, metric_name: str) -> float:
        """Gets the final value of the given metric for the experiment"""
        if metric_name not in self.metrics_history:
            raise ValueError(
                f'Unknown metric {metric_name}: available metrics are'
                f' {list(self.metrics_history.columns)}'
            )
        return self.metrics_history[metric_name].iloc[-1]
    
def create_model(
        settings: ExperimentSettings,
        metrics: list[keras.metrics.Metric],
) -> keras.Model:
    """Create and compile a classification model"""
    
    model_inputs = [
        keras.Input(name=feature, shape=(1,))
        for feature in settings.input_features
    ]

    #use concatenation layer to assemble different inputs into a single tensor
    # For example: [input_1[0][0], input_2[0][0]]

    concatenated_inputs = keras.layers.Concatenate()(model_inputs)
    hidden1 = keras.layers.Dense(10,activation='relu')(concatenated_inputs)
    hidden2 = keras.layers.Dense(10,activation='relu')(hidden1)
    model_output = keras.layers.Dense(1, activation='sigmoid')(hidden2)
    model = keras.Model(inputs=model_inputs, outputs=model_output)

    model.compile(
        optimizer=keras.optimizers.Adam(
            settings.learning_rate
        ),
        loss=keras.losses.BinaryCrossentropy(),
        metrics=metrics
    )
    return model

def train_model(
        experiment_name: str,
        model: keras.Model,
        train_dataset: pd.DataFrame,
        train_labels: np.ndarray,
        validation_dataset: pd.DataFrame,
        validation_labels: np.ndarray,
        settings: ExperimentSettings
) -> Experiment:
    
    # The x parameter of keras.Model.fit can be a dict of arrays, where
    # each array contains the data for one feature.
    train_features={
        feature_name: np.array(train_dataset[feature_name])
        for feature_name in settings.input_features
    }

    validation_features={
        feature_name: np.array(validation_dataset[feature_name])
        for feature_name in settings.input_features
    }

    history = model.fit(
        x=train_features,
        y=train_labels,
        batch_size=settings.batch_size,
        epochs=settings.num_epochs,
        validation_data=(validation_features, validation_labels)
    )

    return Experiment(
        name=experiment_name,
        settings=settings,
        model=model,
        epochs=history.epoch,
        metrics_history=pd.DataFrame(history.history) 
    )

# %%
# Build and train the model

input_features = [
    'Eccentricity',
    'Major_Axis_Length',
    'Area',
]

settings = ExperimentSettings(
    learning_rate=0.001,
    num_epochs=60,
    batch_size=100,
    classification_threshold=0.35,
    input_features=input_features,
)

metrics = [
    keras.metrics.BinaryAccuracy(
        name='accuracy', threshold=settings.classification_threshold
    ),
    keras.metrics.Precision(
        name='precision', thresholds=settings.classification_threshold
    ),
    keras.metrics.Recall(
        name='recall', thresholds=settings.classification_threshold
    ),
    keras.metrics.AUC(num_thresholds=100, name='auc'),
]

# build the model
model = create_model(settings, metrics)

#train the model on the training set

experiment = train_model(
    'baseline', model, train_features, train_labels, 
    validation_features, validation_labels, settings
)
# Out:
# Epoch 1/60
# 31/31 [==============================] - 1s 15ms/step - loss: 0.6581 - accuracy: 0.5338 - precision: 0.4794 - recall: 0.9977 - auc: 0.6602 - val_loss: 0.5912 - val_accuracy: 0.6037 - val_precision: 0.5017 - val_recall: 1.0000 - val_auc: 0.8521
# Epoch 2/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5597 - accuracy: 0.6732 - precision: 0.5684 - recall: 0.9931 - auc: 0.8941 - val_loss: 0.5046 - val_accuracy: 0.7349 - val_precision: 0.6016 - val_recall: 0.9934 - val_auc: 0.9429
# Epoch 3/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4717 - accuracy: 0.7680 - precision: 0.6520 - recall: 0.9862 - auc: 0.9553 - val_loss: 0.4232 - val_accuracy: 0.8058 - val_precision: 0.6773 - val_recall: 0.9803 - val_auc: 0.9610
# Epoch 4/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.8330 - precision: 0.7288 - recall: 0.9733 - auc: 0.9678 - val_loss: 0.3483 - val_accuracy: 0.8556 - val_precision: 0.7513 - val_recall: 0.9539 - val_auc: 0.9686
# Epoch 5/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3187 - accuracy: 0.8734 - precision: 0.7904 - recall: 0.9595 - auc: 0.9728 - val_loss: 0.2900 - val_accuracy: 0.8924 - val_precision: 0.8136 - val_recall: 0.9474 - val_auc: 0.9726
# Epoch 6/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2677 - accuracy: 0.8953 - precision: 0.8291 - recall: 0.9526 - auc: 0.9750 - val_loss: 0.2508 - val_accuracy: 0.9108 - val_precision: 0.8471 - val_recall: 0.9474 - val_auc: 0.9744
# Epoch 7/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2348 - accuracy: 0.9055 - precision: 0.8489 - recall: 0.9488 - auc: 0.9765 - val_loss: 0.2266 - val_accuracy: 0.9160 - val_precision: 0.8571 - val_recall: 0.9474 - val_auc: 0.9755
# Epoch 8/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2151 - accuracy: 0.9124 - precision: 0.8623 - recall: 0.9473 - auc: 0.9772 - val_loss: 0.2123 - val_accuracy: 0.9160 - val_precision: 0.8571 - val_recall: 0.9474 - val_auc: 0.9759
# Epoch 9/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2034 - accuracy: 0.9150 - precision: 0.8671 - recall: 0.9473 - auc: 0.9777 - val_loss: 0.2035 - val_accuracy: 0.9134 - val_precision: 0.8563 - val_recall: 0.9408 - val_auc: 0.9763
# Epoch 10/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.9180 - precision: 0.8732 - recall: 0.9465 - auc: 0.9779 - val_loss: 0.1983 - val_accuracy: 0.9134 - val_precision: 0.8563 - val_recall: 0.9408 - val_auc: 0.9767
# Epoch 11/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9196 - precision: 0.8778 - recall: 0.9442 - auc: 0.9782 - val_loss: 0.1954 - val_accuracy: 0.9186 - val_precision: 0.8667 - val_recall: 0.9408 - val_auc: 0.9763
# Epoch 12/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1893 - accuracy: 0.9206 - precision: 0.8813 - recall: 0.9419 - auc: 0.9785 - val_loss: 0.1935 - val_accuracy: 0.9160 - val_precision: 0.8659 - val_recall: 0.9342 - val_auc: 0.9771
# Epoch 13/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1875 - accuracy: 0.9213 - precision: 0.8826 - recall: 0.9419 - auc: 0.9783 - val_loss: 0.1921 - val_accuracy: 0.9160 - val_precision: 0.8659 - val_recall: 0.9342 - val_auc: 0.9765
# Epoch 14/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1861 - accuracy: 0.9229 - precision: 0.8858 - recall: 0.9419 - auc: 0.9783 - val_loss: 0.1913 - val_accuracy: 0.9108 - val_precision: 0.8598 - val_recall: 0.9276 - val_auc: 0.9766
# Epoch 15/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 0.9242 - precision: 0.8883 - recall: 0.9419 - auc: 0.9786 - val_loss: 0.1908 - val_accuracy: 0.9108 - val_precision: 0.8598 - val_recall: 0.9276 - val_auc: 0.9766
# Epoch 16/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1845 - accuracy: 0.9242 - precision: 0.8883 - recall: 0.9419 - auc: 0.9787 - val_loss: 0.1904 - val_accuracy: 0.9134 - val_precision: 0.8650 - val_recall: 0.9276 - val_auc: 0.9769
# Epoch 17/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1838 - accuracy: 0.9242 - precision: 0.8883 - recall: 0.9419 - auc: 0.9788 - val_loss: 0.1902 - val_accuracy: 0.9134 - val_precision: 0.8650 - val_recall: 0.9276 - val_auc: 0.9769
# Epoch 18/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1834 - accuracy: 0.9236 - precision: 0.8882 - recall: 0.9404 - auc: 0.9788 - val_loss: 0.1901 - val_accuracy: 0.9134 - val_precision: 0.8650 - val_recall: 0.9276 - val_auc: 0.9770
# Epoch 19/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1830 - accuracy: 0.9245 - precision: 0.8901 - recall: 0.9404 - auc: 0.9789 - val_loss: 0.1901 - val_accuracy: 0.9186 - val_precision: 0.8758 - val_recall: 0.9276 - val_auc: 0.9762
# Epoch 20/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1826 - accuracy: 0.9245 - precision: 0.8895 - recall: 0.9412 - auc: 0.9789 - val_loss: 0.1898 - val_accuracy: 0.9186 - val_precision: 0.8758 - val_recall: 0.9276 - val_auc: 0.9761
# Epoch 21/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9245 - precision: 0.8895 - recall: 0.9412 - auc: 0.9791 - val_loss: 0.1898 - val_accuracy: 0.9186 - val_precision: 0.8758 - val_recall: 0.9276 - val_auc: 0.9761
# Epoch 22/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1820 - accuracy: 0.9249 - precision: 0.8902 - recall: 0.9412 - auc: 0.9791 - val_loss: 0.1897 - val_accuracy: 0.9186 - val_precision: 0.8758 - val_recall: 0.9276 - val_auc: 0.9767
# Epoch 23/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.9249 - precision: 0.8902 - recall: 0.9412 - auc: 0.9790 - val_loss: 0.1899 - val_accuracy: 0.9186 - val_precision: 0.8758 - val_recall: 0.9276 - val_auc: 0.9765
# Epoch 24/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9245 - precision: 0.8890 - recall: 0.9419 - auc: 0.9791 - val_loss: 0.1895 - val_accuracy: 0.9186 - val_precision: 0.8758 - val_recall: 0.9276 - val_auc: 0.9764
# Epoch 25/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1815 - accuracy: 0.9249 - precision: 0.8902 - recall: 0.9412 - auc: 0.9792 - val_loss: 0.1898 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9765
# Epoch 26/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9255 - precision: 0.8915 - recall: 0.9412 - auc: 0.9793 - val_loss: 0.1898 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9765
# Epoch 27/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9252 - precision: 0.8908 - recall: 0.9412 - auc: 0.9793 - val_loss: 0.1897 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9766
# Epoch 28/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9255 - precision: 0.8909 - recall: 0.9419 - auc: 0.9793 - val_loss: 0.1900 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9764
# Epoch 29/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9265 - precision: 0.8934 - recall: 0.9412 - auc: 0.9792 - val_loss: 0.1900 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9764
# Epoch 30/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9255 - precision: 0.8909 - recall: 0.9419 - auc: 0.9793 - val_loss: 0.1898 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9763
# Epoch 31/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9255 - precision: 0.8909 - recall: 0.9419 - auc: 0.9792 - val_loss: 0.1898 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9762
# Epoch 32/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1806 - accuracy: 0.9262 - precision: 0.8928 - recall: 0.9412 - auc: 0.9793 - val_loss: 0.1901 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9763
# Epoch 33/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9265 - precision: 0.8928 - recall: 0.9419 - auc: 0.9793 - val_loss: 0.1900 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9763
# Epoch 34/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9262 - precision: 0.8928 - recall: 0.9412 - auc: 0.9793 - val_loss: 0.1902 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9763
# Epoch 35/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9265 - precision: 0.8928 - recall: 0.9419 - auc: 0.9791 - val_loss: 0.1901 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9766
# Epoch 36/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1803 - accuracy: 0.9265 - precision: 0.8928 - recall: 0.9419 - auc: 0.9793 - val_loss: 0.1900 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9764
# Epoch 37/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 0.9265 - precision: 0.8928 - recall: 0.9419 - auc: 0.9791 - val_loss: 0.1902 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9764
# Epoch 38/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 0.9268 - precision: 0.8935 - recall: 0.9419 - auc: 0.9792 - val_loss: 0.1900 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9766
# Epoch 39/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1801 - accuracy: 0.9268 - precision: 0.8935 - recall: 0.9419 - auc: 0.9791 - val_loss: 0.1901 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9765
# Epoch 40/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1801 - accuracy: 0.9268 - precision: 0.8929 - recall: 0.9427 - auc: 0.9791 - val_loss: 0.1901 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9767
# Epoch 41/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1801 - accuracy: 0.9262 - precision: 0.8922 - recall: 0.9419 - auc: 0.9792 - val_loss: 0.1900 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9765
# Epoch 42/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 0.9259 - precision: 0.8927 - recall: 0.9404 - auc: 0.9791 - val_loss: 0.1905 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9766
# Epoch 43/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1801 - accuracy: 0.9259 - precision: 0.8921 - recall: 0.9412 - auc: 0.9792 - val_loss: 0.1903 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9766
# Epoch 44/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9262 - precision: 0.8928 - recall: 0.9412 - auc: 0.9792 - val_loss: 0.1903 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9766
# Epoch 45/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9262 - precision: 0.8933 - recall: 0.9404 - auc: 0.9792 - val_loss: 0.1905 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9764
# Epoch 46/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1798 - accuracy: 0.9259 - precision: 0.8927 - recall: 0.9404 - auc: 0.9793 - val_loss: 0.1909 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9766
# Epoch 47/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1798 - accuracy: 0.9265 - precision: 0.8934 - recall: 0.9412 - auc: 0.9793 - val_loss: 0.1904 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9764
# Epoch 48/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.9262 - precision: 0.8933 - recall: 0.9404 - auc: 0.9792 - val_loss: 0.1907 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9763
# Epoch 49/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9265 - precision: 0.8928 - recall: 0.9419 - auc: 0.9792 - val_loss: 0.1907 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9764
# Epoch 50/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.9268 - precision: 0.8929 - recall: 0.9427 - auc: 0.9792 - val_loss: 0.1906 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9763
# Epoch 51/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9262 - precision: 0.8933 - recall: 0.9404 - auc: 0.9794 - val_loss: 0.1908 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9765
# Epoch 52/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9262 - precision: 0.8916 - recall: 0.9427 - auc: 0.9791 - val_loss: 0.1908 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9760
# Epoch 53/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.9265 - precision: 0.8940 - recall: 0.9404 - auc: 0.9792 - val_loss: 0.1908 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9760
# Epoch 54/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9265 - precision: 0.8923 - recall: 0.9427 - auc: 0.9791 - val_loss: 0.1909 - val_accuracy: 0.9160 - val_precision: 0.8750 - val_recall: 0.9211 - val_auc: 0.9762
# Epoch 55/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9265 - precision: 0.8940 - recall: 0.9404 - auc: 0.9793 - val_loss: 0.1910 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9762
# Epoch 56/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9272 - precision: 0.8936 - recall: 0.9427 - auc: 0.9791 - val_loss: 0.1909 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9762
# Epoch 57/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9259 - precision: 0.8921 - recall: 0.9412 - auc: 0.9793 - val_loss: 0.1908 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9760
# Epoch 58/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9262 - precision: 0.8933 - recall: 0.9404 - auc: 0.9793 - val_loss: 0.1908 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9760
# Epoch 59/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9255 - precision: 0.8926 - recall: 0.9396 - auc: 0.9793 - val_loss: 0.1907 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9761
# Epoch 60/60
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1795 - accuracy: 0.9262 - precision: 0.8939 - recall: 0.9396 - auc: 0.9792 - val_loss: 0.1908 - val_accuracy: 0.9134 - val_precision: 0.8742 - val_recall: 0.9145 - val_auc: 0.9761

# %%
# Save the model and the test data
model.save('rice_classifier.h5')

test_features[input_features].to_csv('test_features.csv', index=False)
np.save('test_labels.npy', test_labels)
